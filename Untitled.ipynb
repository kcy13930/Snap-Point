# %%
import Get_Info as gi
import librosa
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = './sound/김창영_03_13.wav'
gi.basic_info(filepath)
gi.specshow_graph(filepath)
# Out:
# File Name : ./sound/김창영_03_13.wav
# File Duration : 87.8
# Sampling Rate : 20000
# # of Samples : 1756000
# Beat Times : 80
# [ 1.1264  2.2784  3.4304  4.5568  5.6576  6.784   7.8848  9.0112 10.0864
#  11.1872 12.2112 13.2864 14.7712 15.8464 16.9472 18.0992 19.1488 20.224
#  21.248  22.2464 23.296  24.32   25.344  26.3424 27.4432 28.6464 29.7984
#  30.9504 32.0768 33.152  34.2272 35.2256 36.2752 37.2992 38.3488 39.3984
#  40.4224 41.4208 42.4448 43.5968 44.6976 46.0544 47.1552 48.384  49.5616
#  50.6624 51.7376 52.8896 53.9136 54.9632 55.9872 57.088  58.1376 59.2128
#  60.3904 61.568  62.6432 63.6672 64.7168 65.6896 66.7136 67.7632 68.7104
#  69.8368 70.9888 72.2432 73.5232 74.6752 75.7248 76.8    77.952  79.0272
#  80.128  81.2544 82.3552 83.3792 84.4032 85.4016 86.5024 87.5264]

# %%
y, sr = librosa.load('./sound/김창영_03_13.wav', sr=20000)
y_harm, y_perc = librosa.effects.hpss(y)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y_harm, sr=sr, alpha=0.25)
librosa.display.waveplot(y_perc, sr=sr, color='r', alpha=0.5)
plt.title('Harmonic + Percussive')
plt.tight_layout()
plt.show()

tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr, hop_length=500)
beat_frames
# Out:
# array([  44,   89,  134,  178,  221,  265,  308,  352,  394,  437,  477,
#         519,  577,  619,  662,  707,  748,  790,  830,  869,  910,  950,
#         990, 1029, 1072, 1119, 1164, 1209, 1253, 1295, 1337, 1376, 1417,
#        1457, 1498, 1539, 1579, 1618, 1658, 1703, 1746, 1799, 1842, 1890,
#        1936, 1979, 2021, 2066, 2106, 2147, 2187, 2230, 2271, 2313, 2359,
#        2405, 2447, 2487, 2528, 2566, 2606, 2647, 2684, 2728, 2773, 2822,
#        2872, 2917, 2958, 3000, 3045, 3087, 3130, 3174, 3217, 3257, 3297,
#        3336, 3379, 3419])

# %%
y, sr = librosa.load('./sound/김창영_03_13.wav', sr=20000)
y_mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40, hop_length=500)
print(y_mfcc.shape)
print(y.shape)
# Out:
# (40, 3513)
# (1756000,)

# %%
plt.figure(figsize=(10, 4))
librosa.display.specshow(y_mfcc, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %%
y_mfcc
# Out:
# array([[-7.11346130e+02, -6.69170105e+02, -6.44935181e+02, ...,
#         -6.06387451e+02, -6.07810913e+02, -6.14751709e+02],
#        [ 3.52322693e+01,  7.43416290e+01,  9.37719879e+01, ...,
#          1.09228790e+02,  1.05656006e+02,  9.83804703e+01],
#        [ 1.99606419e+01,  2.14428444e+01,  1.73908081e+01, ...,
#          4.55708408e+00,  1.87092960e+00,  9.08956051e-01],
#        ...,
#        [-9.56840396e-01,  9.48355734e-01,  3.21057940e+00, ...,
#          9.22769070e+00,  6.00110817e+00,  3.59011984e+00],
#        [ 9.09618735e-01,  2.08570552e+00,  9.58172023e-01, ...,
#          2.62667322e+00,  2.56249094e+00,  3.06808758e+00],
#        [ 1.67516994e+00,  2.03740835e+00, -5.86545169e-01, ...,
#          3.95649314e-01,  2.60643101e+00,  3.50924206e+00]], dtype=float32)

# %%
gi.lighten(y_mfcc)
# Out:
# array([[-7.1135e+02, -6.6917e+02, -6.4494e+02, ..., -6.0639e+02,
#         -6.0781e+02, -6.1475e+02],
#        [ 3.5230e+01,  7.4340e+01,  9.3770e+01, ...,  1.0923e+02,
#          1.0566e+02,  9.8380e+01],
#        [ 1.9960e+01,  2.1440e+01,  1.7390e+01, ...,  4.5600e+00,
#          1.8700e+00,  9.1000e-01],
#        ...,
#        [-9.6000e-01,  9.5000e-01,  3.2100e+00, ...,  9.2300e+00,
#          6.0000e+00,  3.5900e+00],
#        [ 9.1000e-01,  2.0900e+00,  9.6000e-01, ...,  2.6300e+00,
#          2.5600e+00,  3.0700e+00],
#        [ 1.6800e+00,  2.0400e+00, -5.9000e-01, ...,  4.0000e-01,
#          2.6100e+00,  3.5100e+00]], dtype=float32)

# %%
y, sr = librosa.load('./sound/김창영_03_13.wav', sr=20000)
y_mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40, hop_length=500)
_, beat_frames = librosa.beat.beat_track(y=y, sr=sr, hop_length=500)

for frame_number in beat_frames:
    print("{} of {}".format(frame_number, y_mfcc.T[frame_number-1:frame_number+4].shape))
    print(gi.lighten(y_mfcc.T[frame_number-1:frame_number+4]))
# Out:
# 44 of (5, 40)
# [[-4.9300e+01 -9.2800e+00 -4.1740e+01  9.8300e+00  1.9600e+01 -2.4700e+00
#   -4.3000e+00  1.7430e+01 -2.0800e+00 -1.0210e+01  3.7700e+00  6.5700e+00
#   -4.9100e+00  2.5000e+00  5.2000e+00 -2.1100e+00 -1.4050e+01  1.3990e+01
#   -8.2800e+00  2.3000e-01 -8.4200e+00  9.1800e+00 -8.8900e+00  4.3100e+00
#   -3.6600e+00  5.7600e+00 -1.0030e+01  5.4600e+00 -5.2000e+00 -7.0000e-02
#   -1.8400e+00 -2.0700e+00  1.1900e+00  5.0000e-01 -6.2200e+00  3.0200e+00
#   -5.1400e+00  2.9100e+00 -4.6200e+00  2.0300e+00]
#  [-1.0626e+02 -1.9800e+01 -3.8720e+01  1.4650e+01  1.6180e+01  8.0000e-01
#   -4.9600e+00  2.0130e+01 -2.8200e+00 -1.1570e+01  6.2600e+00  5.3300e+00
#   -2.7300e+00  2.7200e+00  4.6000e+00 -3.6500e+00 -1.2560e+01  1.2240e+01
#   -7.9000e+00  6.8000e-01 -9.3100e+00  7.9500e+00 -7.4300e+00  3.0400e+00
#   -3.0200e+00  4.2100e+00 -9.1800e+00  3.1300e+00 -5.0000e+00 -1.0000e-01
#   -3.9000e+00  1.6000e-01 -1.0400e+00  3.0000e-02 -6.5600e+00  1.5600e+00
# ...
